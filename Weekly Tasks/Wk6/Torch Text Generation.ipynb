# %%
# !pip install torch torchvision torchaudio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torch
#   Downloading torch-2.9.0-cp313-cp313-win_amd64.whl.metadata (30 kB)
# Collecting torchvision
#   Downloading torchvision-0.24.0-cp313-cp313-win_amd64.whl.metadata (5.9 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.9.0-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Collecting filelock (from torch)
#   Using cached filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\oaoyede\appdata\roaming\python\python313\site-packages (from torch) (4.15.0)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in c:\users\oaoyede\appdata\roaming\python\python313\site-packages (from torch) (3.1.6)
# Collecting fsspec>=0.8.5 (from torch)
#   Downloading fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: setuptools in c:\users\oaoyede\appdata\roaming\python\python313\site-packages (from torch) (80.9.0)
# Requirement already satisfied: numpy in c:\users\oaoyede\appdata\roaming\python\python313\site-packages (from torchvision) (2.3.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\oaoyede\appdata\roaming\python\python313\site-packages (from torchvision) (12.0.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\oaoyede\appdata\roaming\python\python313\site-packages (from jinja2->torch) (3.0.3)
# Downloading torch-2.9.0-cp313-cp313-win_amd64.whl (109.3 MB)
#    ---------------------------------------- 0.0/109.3 MB ? eta -:--:--
#    - -------------------------------------- 3.7/109.3 MB 18.9 MB/s eta 0:00:06
#    -- ------------------------------------- 7.6/109.3 MB 18.8 MB/s eta 0:00:06
#    ---- ----------------------------------- 11.5/109.3 MB 18.8 MB/s eta 0:00:06
#    ----- ---------------------------------- 15.2/109.3 MB 18.8 MB/s eta 0:00:06
#    ------- -------------------------------- 19.1/109.3 MB 18.8 MB/s eta 0:00:05
#    -------- ------------------------------- 23.3/109.3 MB 18.8 MB/s eta 0:00:05
#    --------- ------------------------------ 27.3/109.3 MB 18.8 MB/s eta 0:00:05
#    ----------- ---------------------------- 31.2/109.3 MB 18.8 MB/s eta 0:00:05
#    ------------ --------------------------- 35.1/109.3 MB 18.8 MB/s eta 0:00:04
#    -------------- ------------------------- 38.8/109.3 MB 18.8 MB/s eta 0:00:04
#    --------------- ------------------------ 42.7/109.3 MB 18.8 MB/s eta 0:00:04
#    ----------------- ---------------------- 46.7/109.3 MB 18.7 MB/s eta 0:00:04
#    ------------------ --------------------- 50.6/109.3 MB 18.8 MB/s eta 0:00:04
#    ------------------- -------------------- 54.5/109.3 MB 18.8 MB/s eta 0:00:03
#    --------------------- ------------------ 58.2/109.3 MB 18.8 MB/s eta 0:00:03
#    ---------------------- ----------------- 62.1/109.3 MB 18.8 MB/s eta 0:00:03
#    ------------------------ --------------- 66.1/109.3 MB 18.8 MB/s eta 0:00:03
#    ------------------------- -------------- 69.7/109.3 MB 18.7 MB/s eta 0:00:03
#    --------------------------- ------------ 73.9/109.3 MB 18.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 77.6/109.3 MB 18.7 MB/s eta 0:00:02
#    ----------------------------- ---------- 81.8/109.3 MB 18.7 MB/s eta 0:00:02
#    ------------------------------- -------- 85.5/109.3 MB 18.7 MB/s eta 0:00:02
#    -------------------------------- ------- 89.1/109.3 MB 18.6 MB/s eta 0:00:02
#    --------------------------------- ------ 92.8/109.3 MB 18.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 96.5/109.3 MB 18.6 MB/s eta 0:00:01
#    ----------------------------------- --- 100.4/109.3 MB 18.6 MB/s eta 0:00:01
#    ------------------------------------- - 104.6/109.3 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  108.5/109.3 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  109.1/109.3 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------- 109.3/109.3 MB 17.7 MB/s eta 0:00:00
# Downloading torchvision-0.24.0-cp313-cp313-win_amd64.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ------------------- -------------------- 2.1/4.3 MB 18.9 MB/s eta 0:00:01
#    ---------------------------------------- 4.3/4.3 MB 12.2 MB/s eta 0:00:00
# Downloading torchaudio-2.9.0-cp313-cp313-win_amd64.whl (665 kB)
#    ---------------------------------------- 0.0/665.3 kB ? eta -:--:--
#    --------------------------------------- 665.3/665.3 kB 13.2 MB/s eta 0:00:00
# Downloading fsspec-2025.10.0-py3-none-any.whl (200 kB)
# Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    -------------------- ------------------- 1.0/2.0 MB 17.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 12.5 MB/s eta 0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    -------------- ------------------------- 2.4/6.3 MB 22.7 MB/s eta 0:00:01
#    ------------------------------- -------- 5.0/6.3 MB 13.0 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 10.2 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 8.7 MB/s eta 0:00:00
# Using cached filelock-3.20.0-py3-none-any.whl (16 kB)
# Installing collected packages: mpmath, sympy, networkx, fsspec, filelock, torch, torchvision, torchaudio
#
#    ---------------------------------------- 0/8 [mpmath]
#    ---------------------------------------- 0/8 [mpmath]
#    ---------------------------------------- 0/8 [mpmath]
#    ---------------------------------------- 0/8 [mpmath]
#    ---------------------------------------- 0/8 [mpmath]
#    ---------------------------------------- 0/8 [mpmath]
#    ---------------------------------------- 0/8 [mpmath]
#    ---------------------------------------- 0/8 [mpmath]
#    ---------------------------------------- 0/8 [mpmath]
#    ---------------------------------------- 0/8 [mpmath]
#    ---------------------------------------- 0/8 [mpmath]
#    ---------------------------------------- 0/8 [mpmath]
#    ---------------------------------------- 0/8 [mpmath]
#    ---------------------------------------- 0/8 [mpmath]
#    ---------------------------------------- 0/8 [mpmath]
#    ---------------------------------------- 0/8 [mpmath]
#    ---------------------------------------- 0/8 [mpmath]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    --------------- ------------------------ 3/8 [fsspec]
#    --------------- ------------------------ 3/8 [fsspec]
#    --------------- ------------------------ 3/8 [fsspec]
#    --------------- ------------------------ 3/8 [fsspec]
#    --------------- ------------------------ 3/8 [fsspec]
#    --------------- ------------------------ 3/8 [fsspec]
#    --------------- ------------------------ 3/8 [fsspec]
#    --------------- ------------------------ 3/8 [fsspec]
#    --------------- ------------------------ 3/8 [fsspec]
#    --------------- ------------------------ 3/8 [fsspec]
#    -------------------- ------------------- 4/8 [filelock]
#    -------------------- ------------------- 4/8 [filelock]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------- -------------- 5/8 [torch]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ------------------------------ --------- 6/8 [torchvision]
#    ----------------------------------- ---- 7/8 [torchaudio]
#    ----------------------------------- ---- 7/8 [torchaudio]
#    ----------------------------------- ---- 7/8 [torchaudio]
#    ----------------------------------- ---- 7/8 [torchaudio]
#    ----------------------------------- ---- 7/8 [torchaudio]
#    ----------------------------------- ---- 7/8 [torchaudio]
#    ----------------------------------- ---- 7/8 [torchaudio]
#    ----------------------------------- ---- 7/8 [torchaudio]
#    ----------------------------------- ---- 7/8 [torchaudio]
#    ----------------------------------- ---- 7/8 [torchaudio]
#    ----------------------------------- ---- 7/8 [torchaudio]
#    ----------------------------------- ---- 7/8 [torchaudio]
#    ----------------------------------- ---- 7/8 [torchaudio]
#    ----------------------------------- ---- 7/8 [torchaudio]
#    ---------------------------------------- 8/8 [torchaudio]
#
# Successfully installed filelock-3.20.0 fsspec-2025.10.0 mpmath-1.3.0 networkx-3.5 sympy-1.14.0 torch-2.9.0 torchaudio-2.9.0 torchvision-0.24.0
#   WARNING: The script isympy.exe is installed in 'C:\Users\OAOyede\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts torchfrtrace.exe and torchrun.exe are installed in 'C:\Users\OAOyede\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch
print(torch.__version__)
# Out:
# 2.9.0+cpu

# %%
import nltk, torch
from nltk.tokenize import word_tokenize
nltk.download('punkt')

text = open("sample.txt").read().lower()
tokens = word_tokenize(text)
vocab = sorted(set(tokens))
stoi = {w:i for i,w in enumerate(vocab)}
itos = {i:w for w,i in stoi.items()}

data = torch.tensor([stoi[w] for w in tokens])
block = 40
def get_batch(bs=32):
    ix = torch.randint(len(data)-block, (bs,))
    x = torch.stack([data[i:i+block] for i in ix])
    y = torch.stack([data[i+1:i+block+1] for i in ix])
    return x,y
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\OAOyede\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import torch.nn as nn
class RNNModel(nn.Module):
    def __init__(self, vocab_size, hidden=128):
        super().__init__()
        self.embed = nn.Embedding(vocab_size, hidden)
        self.rnn = nn.RNN(hidden, hidden, batch_first=True)
        self.fc = nn.Linear(hidden, vocab_size)
    def forward(self,x,h=None):
        x = self.embed(x)
        out,h = self.rnn(x,h)
        return self.fc(out),h

# %%
class LSTMModel(nn.Module):
    def __init__(self, vocab_size, hidden=128):
        super().__init__()
        self.embed = nn.Embedding(vocab_size, hidden)
        self.lstm = nn.LSTM(hidden, hidden, batch_first=True)
        self.fc = nn.Linear(hidden, vocab_size)
    def forward(self,x,h=None):
        x = self.embed(x)
        out,h = self.lstm(x,h)
        return self.fc(out),h

# %%
import torch.optim as optim
def train(model,epochs=10):
    opt = optim.Adam(model.parameters(),lr=0.003)
    loss_fn = nn.CrossEntropyLoss()
    for e in range(epochs):
        x,y = get_batch()
        logits,_ = model(x)
        loss = loss_fn(logits.view(-1,len(vocab)),y.view(-1))
        opt.zero_grad(); loss.backward(); opt.step()
        if (e+1)%2==0:
            print(f"Epoch {e+1}, Loss={loss.item():.3f}")

# %%
# Make sure text exists (if you used a tiny snippet)
MIN_TOKENS = 400   # increase if you want longer contexts
if len(data) < MIN_TOKENS:
    # repeat the text to reach a safe length
    reps = (MIN_TOKENS // max(1, len(data))) + 1
    data = data.repeat(reps)

# Auto-adjust block so it's always valid
block = min(block, max(10, len(data) - 2))  # keep at least 10
print("Data length:", len(data), " | block:", block)
# Out:
# Data length: 418  | block: 40

# %%
def get_batch(bs=32):
    # guarantee we can sample
    high = len(data) - block - 1
    if high <= 0:
        # fallback: shrink block temporarily if text is still too short
        b = max(5, len(data) - 2)
        x = data[:b].unsqueeze(0).repeat(bs, 1)
        y = data[1:b+1].unsqueeze(0).repeat(bs, 1)
        return x, y

    ix = torch.randint(high, (bs,))
    x = torch.stack([data[i:i+block] for i in ix])
    y = torch.stack([data[i+1:i+block+1] for i in ix])
    return x, y

# %%
model = RNNModel(len(vocab))
train(model)
# Out:
# Epoch 2, Loss=3.329
# Epoch 4, Loss=2.978
# Epoch 6, Loss=2.594
# Epoch 8, Loss=2.173
# Epoch 10, Loss=1.735

# %%
def generate(model,start='the',length=50):
    model.eval()
    ids=[stoi[start]] if start in stoi else [0]
    h=None
    for _ in range(length):
        x=torch.tensor([[ids[-1]]])
        logits,h=model(x,h)
        probs=torch.softmax(logits[0,-1],dim=0)
        next_id=torch.multinomial(probs,1).item()
        ids.append(next_id)
    return ' '.join(itos[i] for i in ids)

print(generate(model,'the student'))
# Out:
# . word a rnn was about an an a student student there was student in an rnn to soon . a networks there remember there they learning long could remember remember remember how remember could realised word learning rnn how in predict context built upon much upon . they built long
